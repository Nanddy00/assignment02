# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import numpy as np

# %%
import seaborn as sb

# %%
import pandas

# %%
from bs4 import BeautifulSoup

# %%
ass1=pandas.read_csv("C:\\Users\\aedpu\\Downloads\\nanddy.csv")

# %%
ass1
# Out:
#      Unnamed: 0                Company       City  Starting Year  \
# 0             0          Urban Company    Gurgaon           2014
# 1             1              Classplus      Noida           2018
# 2             2                  Paytm      Noida           2010
# 3             3                   Apna     Mumbai           2019
# 4             4               Razorpay  Bengaluru           2014
# ..          ...                    ...        ...            ...
# 295         295               SafexPay      Thane           2017
# 296         296               Pariksha       Pune           2015
# 297         297                  Fyllo  Bengaluru           2019
# 298         298               CredFlow  New Delhi           2019
# 299         299  HalaPlay Technologies  Bengaluru           2016
#
#                                               Founders  \
# 0    Abhiraj Singh Bhal, Raghav Chandra, Varun Khaitan
# 1    Bhaswat Agarwal, Bikash Dash, Mukul Rustagi, N...
# ...

# %% [markdown]
# # SCATTER PLOT

# %%
plt.scatter(ass['Starting Year'],ass['Funding Round'])

# %% [markdown]
# # BAR CHART

# %%
plt.bar(ass['Starting Year'],ass['No. of Investors'])
# Out:
# <BarContainer object of 300 artists>

# %%
plt.plot(ass['Starting Year'],ass['Funding Round'],linestyle='dotted')

# %% [markdown]
# # PIE CHART

# %%
plt.pie(ass['No. of Investors'],labels=ass['City'])
# Out:
# ([<matplotlib.patches.Wedge at 0x233a835da00>,
# ...
#  [Text(1.0864571742518743, 0.1720779140872905, 'Thane'),
#   Text(-0.3399186987098806, 1.0461621663333949, 'Pune'),
#   Text(-0.7778174410990705, -0.7778174775113338, 'Bengaluru'),
#   Text(5.149471664411206e-08, -1.0999999999999988, 'New Delhi'),
#   Text(0.8899187331606258, -0.6465637233635886, 'Bengaluru')])

# %% [markdown]
# # DISTRIBUTION PLOT

# %%
sb.set(style='darkgrid')

# %%
sb.distplot(ass['Funding Round'])
# Out:
# C:\Users\aedpu\AppData\Local\Temp\ipykernel_6564\2270356666.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sb.distplot(ass['Funding Round'])
# <Axes: xlabel='Funding Round', ylabel='Density'>

# %%
asst
# Out:
#      Unnamed: 0                Company       City  Starting Year  \
# 295         295               SafexPay      Thane           2017
# 296         296               Pariksha       Pune           2015
# 297         297                  Fyllo  Bengaluru           2019
# 298         298               CredFlow  New Delhi           2019
# 299         299  HalaPlay Technologies  Bengaluru           2016
#
#                                               Founders  \
# 295                                         Ravi Gupta
# 296  Deepak Choudhary, Karanvir Singh Shekhawat, Ut...
# 297        Sachin Gautam, Sudhanshu Rai, Sumit Sheoran
# 298                                     Kunal Aggarwal
# 299                                     Swapnil Saurav
#
#                                             Industries  \
# 295                                  FinTech, Payments
# 296    E-Learning, EdTech, Education, Skill Assessment
# 297  Agriculture, AgTech, Artificial Intelligence, ...
# ...

# %%
time=np.arange(10,50,0.04)

# %%
time
# Out:
# array([10.  , 10.04, 10.08, 10.12, 10.16, 10.2 , 10.24, 10.28, 10.32,
#        10.36, 10.4 , 10.44, 10.48, 10.52, 10.56, 10.6 , 10.64, 10.68,
#        10.72, 10.76, 10.8 , 10.84, 10.88, 10.92, 10.96, 11.  , 11.04,
#        11.08, 11.12, 11.16, 11.2 , 11.24, 11.28, 11.32, 11.36, 11.4 ,
#        11.44, 11.48, 11.52, 11.56, 11.6 , 11.64, 11.68, 11.72, 11.76,
#        11.8 , 11.84, 11.88, 11.92, 11.96, 12.  , 12.04, 12.08, 12.12,
#        12.16, 12.2 , 12.24, 12.28, 12.32, 12.36, 12.4 , 12.44, 12.48,
#        12.52, 12.56, 12.6 , 12.64, 12.68, 12.72, 12.76, 12.8 , 12.84,
#        12.88, 12.92, 12.96, 13.  , 13.04, 13.08, 13.12, 13.16, 13.2 ,
#        13.24, 13.28, 13.32, 13.36, 13.4 , 13.44, 13.48, 13.52, 13.56,
#        13.6 , 13.64, 13.68, 13.72, 13.76, 13.8 , 13.84, 13.88, 13.92,
#        13.96, 14.  , 14.04, 14.08, 14.12, 14.16, 14.2 , 14.24, 14.28,
#        14.32, 14.36, 14.4 , 14.44, 14.48, 14.52, 14.56, 14.6 , 14.64,
# ...

# %%
amplitude=np.sin(time)

# %% [markdown]
# # SINE WAVE

# %%
plt.plot(time,amplitude)

# %% [markdown]
# # RELATIONSHIP PLOT

# %%
sb.relplot(x='No. of Investors',y='Funding Round',data=ass1,col='No. of Employees',hue="Starting Year",style="Starting Year",kind="line") #line or scatter

# %% [markdown]
# # SCATER BOX PLOT

# %%
sb.catplot(x='Starting Year',y='No. of Investors',kind='box',data=asst)

# %% [markdown]
# # REGRESSION PLOT

# %%
sb.regplot(x='Starting Year',y='No. of Investors',data=ass1)
# Out:
# <Axes: xlabel='Starting Year', ylabel='No. of Investors'>

# %% [markdown]
# # PAIR PLOT

# %%
sb.pairplot(ass1)

# %% [markdown]
# # PAIR PLOT

# %%
sb.pairplot(ass1,hue='City',palette='Set1')
